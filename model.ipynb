# %%
import tensorflow
from tensorflow.keras.preprocessing import image
from tensorflow.keras.layers import GlobalMaxPooling2D
from tensorflow.keras.applications.resnet50 import ResNet50,preprocess_input
import numpy as np
from numpy.linalg import norm
import os
from tqdm import tqdm
import pickle

# %%
model = ResNet50(weights='imagenet' , include_top=False , input_shape=(224,224,3))
model.trainable = False 
model = tensorflow.keras.Sequential([
    model ,
    GlobalMaxPooling2D()
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  global_max_pooling2d (Glob  (None, 2048)              0
#  alMaxPooling2D)
#
# ...
# Total params: 23587712 (89.98 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 23587712 (89.98 MB)
# _________________________________________________________________

# %%
def extract_features(img_path , model):
    img = image.load_img(img_path , target_size=(224,224))
    img = image.img_to_array(img)
    img = np.expand_dims(img , axis = 0)
    img = preprocess_input(img)
    result = model.predict(img).flatten()
    result = result / norm(result)
    return result

# %%
filenames = []
for file in os.listdir('images'):
    filenames.append(os.path.join('images' , file))
pickle.dump(filenames , open('filenames_me.pkl' , 'wb'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\Projects\Fashion Reccomendation\model.ipynb Cell 4 line 2
#       <a href='vscode-notebook-cell:/d%3A/Projects/Fashion%20Reccomendation/model.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> filenames = []
# ----> <a href='vscode-notebook-cell:/d%3A/Projects/Fashion%20Reccomendation/model.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> for file in os.listdir('images'):
#       <a href='vscode-notebook-cell:/d%3A/Projects/Fashion%20Reccomendation/model.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a>     filenames.append(os.path.join('images' , file))
#       <a href='vscode-notebook-cell:/d%3A/Projects/Fashion%20Reccomendation/model.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a> pickle.dump(filenames , open('filenames_me.pkl' , 'wb'))
#
# NameError: name 'os' is not defined

# %%
feature_list = []
for file in tqdm(filenames[:5000]) : 
    feature_list.append(extract_features(file , model))
feature_list.shape  

pickle.dump(feature_list , open('embeddings.pkl' , 'wb'))
pickle.dump(filenames , open('filenames.pkl' , 'wb'))
# Out:
# ...
#   9%|▉         | 462/5000 [03:20<11:02,  6.85it/s]
# ...
# ...
# 100%|██████████| 5000/5000 [45:05<00:00,  1.85it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\Projects\Fashion Reccomendation\model.ipynb Cell 5 line 4
#       <a href='vscode-notebook-cell:/d%3A/Projects/Fashion%20Reccomendation/model.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> for file in tqdm(filenames[:5000]) :
#       <a href='vscode-notebook-cell:/d%3A/Projects/Fashion%20Reccomendation/model.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a>     feature_list.append(extract_features(file , model))
# ----> <a href='vscode-notebook-cell:/d%3A/Projects/Fashion%20Reccomendation/model.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> feature_list.shape
#       <a href='vscode-notebook-cell:/d%3A/Projects/Fashion%20Reccomendation/model.ipynb#W4sZmlsZQ%3D%3D?line=5'>6</a> pickle.dump(feature_list , open('embeddings.pkl' , 'wb'))
# ...

# %%
#Trained data on google colab

# %%
# import pickle
# pickle_final = {}
# with open('embeddings3.pkl' , 'rb') as f:
#     pickle_final.update(pickle.load(f))
# with open('embeddings5.pkl' , 'rb') as f:
#     pickle_final.update(pickle.load(f))
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# d:\Projects\Fashion Reccomendation\model.ipynb Cell 7 line 4
#       <a href='vscode-notebook-cell:/d%3A/Projects/Fashion%20Reccomendation/model.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> pickle_final = {}
#       <a href='vscode-notebook-cell:/d%3A/Projects/Fashion%20Reccomendation/model.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> with open('embeddings3.pkl' , 'rb') as f:
# ----> <a href='vscode-notebook-cell:/d%3A/Projects/Fashion%20Reccomendation/model.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a>     pickle_final.update(pickle.load(f))
#       <a href='vscode-notebook-cell:/d%3A/Projects/Fashion%20Reccomendation/model.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a> with open('embeddings5.pkl' , 'rb') as f:
# ...

# %%
# result = []
# for d in os.listdir('D:\Projects\Fashion Reccomendation'):
#     if (d.endswith('3.pkl') or d.endswith('5.pkl')):
#         with open(os.path.join('D:\Projects\Fashion Reccomendation', d), 'rb') as f:
#             print(f)
#             content = pickle.load(f)
#         result.append(content)
# with open('result.pkl', 'wb') as out:
#     pickle.dump(result, out, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# <_io.BufferedReader name='D:\\Projects\\Fashion Reccomendation\\embeddings3.pkl'>
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# d:\Projects\Fashion Reccomendation\model.ipynb Cell 8 line 6
#       <a href='vscode-notebook-cell:/d%3A/Projects/Fashion%20Reccomendation/model.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a>         with open(os.path.join('D:\Projects\Fashion Reccomendation', d), 'rb') as f:
#       <a href='vscode-notebook-cell:/d%3A/Projects/Fashion%20Reccomendation/model.ipynb#X10sZmlsZQ%3D%3D?line=4'>5</a>             print(f)
# ----> <a href='vscode-notebook-cell:/d%3A/Projects/Fashion%20Reccomendation/model.ipynb#X10sZmlsZQ%3D%3D?line=5'>6</a>             content = pickle.load(f)
#       <a href='vscode-notebook-cell:/d%3A/Projects/Fashion%20Reccomendation/model.ipynb#X10sZmlsZQ%3D%3D?line=6'>7</a>         result.append(content)
# ...

# %%
# Out:
# ['app.py', 'archive', 'archive.zip', 'embeddings1.pkl', 'embeddings2.pkl', 'embeddings3.pkl', 'embeddings4.pkl', 'embeddings5.pkl', 'filenames.pkl', 'images', 'model.ipynb']
